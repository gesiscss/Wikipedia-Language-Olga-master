# %% [markdown]
# # Collect text and links from Wiki articles

# %% [markdown]
# Example of API queries:
# #links to Wiki API all plane text and lead
#
# https://de.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Gleichstellungsbeauftragte&exintro=&explaintext=&redirects=&exsentences=10&formatversion=2
#
# https://de.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Gleichstellungsbeauftragte&exintro=&explaintext=&redirects=&formatversion=2

# %%
#from wikitools2 import wiki, api #new version of wikitools
from wikitools import wiki, api
import urllib, json
import re, urlparse
import pprint
import mwparserfromhell
from mwparserfromhell.nodes import Wikilink
import pandas as pd

def load_simple_json(filename):
    with open(filename, 'r') as f:
        return json.load(f)
    
def check_categories(page):
    categories_f=["Kategorie:Frau"]
    categories_m=["Kategorie:Mann"]
    #http://de.wikipedia.org/w/api.php?action=query&titles=Hebamme&prop=categories
    l="de" 
    site = wiki.Wiki("http://"+l+".wikipedia.org/w/api.php")
    params={'action':'query','titles':page,'prop':'categories','format':'json','continue':'','redirects':''}
    request = api.APIRequest(site, params)
    for result in request.queryGen():
        if result["query"]["pages"].values()[0].get("categories"):
            for i in result["query"]["pages"].values()[0]["categories"]:
                if i["title"] in categories_f:
                    return "Frau" 
                elif i["title"] in categories_m:
                    return "Mann"   
        else:
            return None   
    return None
def query_de_wiki(site,params):
    req = api.APIRequest(site, params)
    res=req.query()
    return res["query"]["pages"][0]["extract"]
    
def get_links_from_text(title):   
    language="de"
    site = wiki.Wiki("http://" + language + ".wikipedia.org/w/api.php")
    params = {'action':'parse', 'page':title, 'prop':'wikitext'}
    req = api.APIRequest(site, params) 
  
    alllinklist = []
    male_person=[]
    female_person=[]
    all_text=""
    lead_text=""
    
    #store all raw text
    params={'action':'query','titles':title,'prop':'extracts','explaintext':'','redirects':'','formatversion':'2'}
    all_text=query_de_wiki(site,params)
            
    #store lead raw text
    params['exintro']=''
    lead_text=query_de_wiki(site,params)
            
    if True:
        #try:
        #res= req.query(querycontinue=False) #False ?
        for res in req.queryGen():
            #wiki text with links and text as wiki markup language
            text = res['parse']['wikitext']['*']
            #a=mwparserfromhell.parse(text)
            #print a.strip_code()

            #parse all links
            filtered_code = mwparserfromhell.parse(text).filter_wikilinks()
            for node in filtered_code: 
                link = node.title
                if ":" not in link:
                    if link is not None:
                        strlink = link.encode("utf-8").decode("utf-8").replace(' ', '_')
                        # strlink=urllib.quote(strlink.encode("utf-8"))
                        if strlink not in alllinklist:
                            alllinklist.append(strlink)
                            #Kategorie:Frau, Kategorie:Mann
                            #check the category of the link
                            gender=check_categories(strlink)
                            if gender =="Mann":
                                male_person.append(strlink)
                            elif gender=="Frau":
                                female_person.append(strlink)
                                

        return alllinklist,male_person,female_person,all_text,lead_text  
            
Dump = {} 
data=pd.read_csv("de/wiki/all_wiki_pages.csv",sep='\t', encoding='utf-8',index_col=0)   
pages=data.WikiName.values  
#TODO: check whether file exist
with open('de/wiki/all_data_from pages.json', 'r') as in_f:
    Dump=json.load(in_f)
print "We already stored", len(Dump), "professions", "out of ",len(pages)
#pages=["Gleichstellungsbeauftragte","Lehrer","Arzt"]
for title in pages:
    if title not in Dump:
        alllink,m,f,all_text,lead_text = get_links_from_text( title)
        print len(alllink)
        Dump.update({title:{"all_link":alllink,"male_person":m,"female_person":f,"male_person_amount":len(m),
                                "female_person_amount":len(f),"text":all_text,"lead":lead_text}})
# Out:
# We already stored 885 professions out of  885

# %%
with open('de/wiki/all_data_from pages.json', 'w') as out:
    json.dump(Dump, out, indent=4, sort_keys=True)

# %% [markdown]
# # Store redirection bias ,gender of article and labour market in one file

# %%
import json
import pandas as pd

def load_simple_json(filename):
    with open(filename, 'r') as f:
        return json.load(f,encoding="utf-8")
all_wiki_pages=pd.read_csv("de/wiki/all_wiki_pages.csv",sep='\t', encoding='utf-8',index_col=0)##885
about_pages=load_simple_json('de/wiki/all_data_from pages.json')
about_pages=pd.DataFrame.from_dict(about_pages,orient="index")#885

#==============add Bias
about_pages["Bias"]=about_pages.apply(lambda x:all_wiki_pages[all_wiki_pages.WikiName.isin([x.name])].Bias.values[0],axis =1)

#==============add profession gender
import copy
f_val=load_simple_json('de/wiki/f_page_validated.json')
f_amb=load_simple_json('de/wiki/f_page_ambigious.json')
n_pages=load_simple_json('de/wiki/n_page_validated.json')
n_pages2=all_wiki_pages[(all_wiki_pages.Bias=="neutral")&(all_wiki_pages.Name!=all_wiki_pages.WikiName)].WikiName.values#10 neutral names of professions
n_pages_all=copy.deepcopy(n_pages)
n_pages_all.extend(n_pages2)
f_val_all=copy.deepcopy(f_val)
f_val_all.extend(f_amb)

def identify_gender(f_val_all,n_pages_all,x):
    if x.name in f_val_all:
        return "female"
    elif x.name in n_pages_all:
        return "neutral"
    else:
        return "male"
about_pages["prof_gender"]=about_pages.apply(lambda x: identify_gender(f_val_all,n_pages_all,x),axis=1)
#==check data
#print len(n_pages2)+len(n_pages)#11+33
#print len(f_val_all)#18 (6bias+12)
#all_wiki_pages[all_wiki_pages.Bias.isin(["neutral"])]#f+n=73(6+67)
#about_pages[about_pages.index.isin(set(set(all_wiki_pages[all_wiki_pages.Bias.isin(["neutral"])].WikiName)-set(n_pages_all))-set(f_val_all))]
#print about_pages[(about_pages.Bias=="male")&(about_pages.prof_gender!="male")]
#print about_pages[(about_pages.Bias=="female")&(about_pages.prof_gender!="female")]

# %%
#==============add labour market data
all_together=pd.read_csv("de/all_labour.csv",sep='\t', encoding='utf-8',index_col=0) 
list_of_extra_names=list(all_wiki_pages[all_wiki_pages.WikiName!=all_wiki_pages.Name].Name.values)#48
list_of_extra_wikinames=list(all_wiki_pages[all_wiki_pages.WikiName!=all_wiki_pages.Name].WikiName.values)


#male
df_most_m=all_together[all_together.Frauen<50.0]
#wikipedia page names for male dominated professions
m_=list(all_wiki_pages[all_wiki_pages.Name.isin(df_most_m.name)].WikiName.values) #547
#female_names of male dominated professions
m_m=list(all_wiki_pages[all_wiki_pages.Oppositgender.isin(df_most_m.name)].WikiName.values) #6
print len(m_),len(m_m)
m_.extend(m_m)#553
print len(m_)#553

#another names of male prfessions 
m_most_m_other=df_most_m[df_most_m.name.isin(list_of_extra_names)].name#32
print len(m_most_m_other)#32
m_other=list(all_wiki_pages[all_wiki_pages.Name.isin(m_most_m_other)].WikiName.values)
m_.extend(m_other)#
print len(m_)#585
male_most_people=about_pages[about_pages.index.isin(m_)]#553
print len(male_most_people)


#female
#get where more than 50% of women involved
df_most_f=all_together[all_together.Frauen>=50.0]#311

print len(df_most_f)
f_=list(all_wiki_pages[all_wiki_pages.Name.isin(df_most_f.name)].WikiName.values) #306
#female names of female dominated professions
f_f=list(all_wiki_pages[all_wiki_pages.Oppositgender.isin(df_most_f.name)].WikiName.values) #12
print len(f_),len(f_f)
f_.extend(f_f)#318
print len(f_)
#other names f female professions
f_most_f_other=df_most_f[df_most_f.name.isin(list_of_extra_names)].name#7
f_other=list(all_wiki_pages[all_wiki_pages.Name.isin(f_most_f_other)].WikiName.values)
f_.extend(f_other)#
print len(set(f_)) #318
#309+535=844 over 885
female_most_people=about_pages[about_pages.index.isin(f_)]#318
print "",len(female_most_people)


print "No statistical data for ",len(list(set(set(about_pages.index)-set(m_))-set(f_)))," profesions:"
print list(set(set(about_pages.index)-set(m_))-set(f_))#14
#553+318=871 (871+14)=885
# Out:
# 547 6
# 553
# 32
# 585
# 553
# 311
# 306 12
# 318
# 318
#  318
# No statistical data for  14  profesions:
# [u'Fachpraktiker', u'Trainer', u'Techniker', u'Kaufmann', u'Sachverst\xe4ndiger', u'Verfahrensmechaniker', u'Facharbeiter', u'Angestellter', u'Fachleiter', u'Produktionshelfer', u'Helfer', u'Fachkraft', u'Meister', u'Fachkaufmann']

# %%
male_most_people["labor_market_domin"]=male_most_people.apply(lambda x: "male",axis=1)#"male"
female_most_people["labor_market_domin"]=female_most_people.apply(lambda x: "female",axis=1)#"female"
#all data
df_all_labour=pd.concat([male_most_people,female_most_people])

def do_smth(x):
    if x.name in df_all_labour.index.values:
        return df_all_labour[df_all_labour.index==x.name].labor_market_domin.values[0]
    else:
        return None
about_pages["labor_market_domin"]=about_pages.apply(lambda x: do_smth(x),axis=1)
about_pages["profession"]=about_pages.apply(lambda x: x.name,axis=1)
#!!!!Store it in file==================================!!!!!!!!!!!!!!=====================
about_pages.to_csv('de/all_data_bias_labour_gender.csv', sep='\t', encoding='utf-8')

about_pages
# Out:
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#                                           male_person_amount  \
# Abfallbeauftragter                                         0
# Abt                                                        4
# Account-Manager                                            0
# Altenpflegehelfer                                          0
# Altenpfleger                                               0
# Amtsanwalt                                                 0
# Angestellter                                               7
# Animateur                                                  0
# Anlagenelektriker                                          0
# Anlagenmechaniker                                          0
# Anwendungsprogrammierer                                    0
# Anästhesietechnischer Assistent                            0
# Apothekenfacharbeiter                                      0
# Apotheker                                                 20
# Apothekerassistent                                         0
# Apothekerin                                                0
# Arbeitserzieher                                            0
# Arbeitsvermittler                                          0
# Architekt                                                  2
# Archivar                                                   1
# Arrangeur                                                 80
# Artist (Darsteller)                                        2
# Arzt                                                       5
# Asphaltbauer                                               0
# Assistenzarzt                                              0
# Astronom                                                   3
# Astrophysiker                                              0
# Au-pair                                                    0
# Audiodesign                                                0
# Aufbereitungsmechaniker                                    0
# ...                                                      ...
# Wildhüter                                                  0
# Winzer                                                     4
# Wirtschaftsassistent                                       0
# Wirtschaftsfachwirt                                        0
# Wirtschaftsjurist                                          0
# Wirtschaftsprüfer                                          1
# Wissenschaftlicher Mitarbeiter                             0
# Wächter                                                    0
# Wärme-, Kälte- und Schallschutzisolierer                   0
# Yogalehrer                                                 0
# Zahlmeister                                                0
# Zahnarzt                                                  10
# Zahnmedizinischer Fachangestellter                         0
# Zahnmedizinischer Fachassistent                            0
# Zahnmedizinischer Prophylaxeassistent                      0
# Zahnmedizinischer Verwaltungsassistent                     0
# Zahntechniker                                              0
# Zauberer                                                  38
# Zerspanungsmechaniker                                      0
# Zimmerer                                                   9
# Zimmerpolier                                               0
# Zinngießer                                                 3
# Zoologe                                                   48
# Zootechniker                                               1
# Zupfinstrumentenmacher                                     4
# Zuschneider                                                0
# Zusteller                                                 22
# Zweiradmechaniker                                          0
# Änderungsschneider                                         0
# Übersetzer                                                 1
#
#                                                                                    all_link  \
# Abfallbeauftragter                        [Unternehmer, Kreislaufwirtschaft, Abfallbesei...
# Abt                                       [Kirchliche_Heraldik, Galero, Chorkleidung, Ha...
# Account-Manager                           [Vertrieb, Kunde, Unternehmen, Key-Account-Man...
# Altenpflegehelfer                         [Hessen, Nordrhein-Westfalen, Baden-Württember...
# Altenpfleger                              [Ambulante_Pflege, Häusliche_Krankenpflege, So...
# Amtsanwalt                                [Siegelmarke, Beamter_(Deutschland), Gehobener...
# Angestellter                              [Arbeitnehmer, Arbeiter, Arbeitsrecht, Sozialr...
# Animateur                                 [Unterhaltungskünstler, Tourismus, Tagung, Ver...
# Anlagenelektriker                         [Berufsausbildung, Österreich, Elektrotechnik_...
# Anlagenmechaniker                         [Ausbildungsberuf, Berufsbildungsgesetz_(Deuts...
# Anwendungsprogrammierer                   [Programmierer, Anwendungsprogramm, Customizin...
# Anästhesietechnischer Assistent           [Ausbildungsberuf, Gesundheits-_und_Krankenpfl...
# Apothekenfacharbeiter                     [Deutsche_Demokratische_Republik, Apotheke, Po...
# Apotheker                                 [Léo_Apotheker, Arzneimittel, Bundes-Apotheker...
# Apothekerassistent                        [Bundesgesetz_(Deutschland), Deutschland, Verw...
# Apothekerin                               [Apotheker, Die_Apothekerin, Die_Apothekerin_(...
# Arbeitserzieher                           [Wilhelmsdorf_(Württemberg), Bodensee, Psychol...
# Arbeitsvermittler                         [Bundesagentur_für_Arbeit, Jobcenter, Öffentli...
# Architekt                                 [Erz-, Gebäude, Bauwerk, Hochbau, Architektur,...
# Archivar                                  [Archivar_(Zeitschrift), Archivgut, Verband_de...
# Arrangeur                                 [Arrangement, Komponist, Komposition_(Musik), ...
# Artist (Darsteller)                       [Artistik, Kontorsionistin, Darstellende_Kunst...
# Arzt                                      [Arzt_(Begriffsklärung), Trauma_(Medizin), Kra...
# Asphaltbauer                              [Ausbildungsberuf, Decke_(Straßenbau), Berufsb...
# Assistenzarzt                             [Approbation_(Heilberufe), Arzt, Facharzt, Obe...
# Astronom                                  [Jan_Vermeer, Galileo_Galilei, Stern, Gestirn,...
# Astrophysiker                             [physik, Universum, Astrophysik, Universität, ...
# Au-pair                                   [Junger_Volljähriger, Staat, Jugendlicher, Fra...
# Audiodesign                               [Digitalisierung, Geräuschemacher, Tontechnike...
# Aufbereitungsmechaniker                   [Steinkohle, Sand, Kies, Naturstein, Feuerfest...
# ...                                                                                     ...
# Wildhüter                                 [Wildbannforst, Wildhube, Jagdrecht, Hege, Jag...
# Winzer                                    [Champagne-Ardenne, Edle_Weinrebe, Jost_Amman,...
# Wirtschaftsassistent                      [Ausbildungsberuf, Berufsschule, Berufskolleg,...
# Wirtschaftsfachwirt                       [Meister#Abschlüsse_auf_Meisterebene, Aufstieg...
# Wirtschaftsjurist                         [Volljurist, Bachelor_of_Laws, Master_of_Laws,...
# Wirtschaftsprüfer                         [Beruf, öffentliches_Amt, Wirtschaftsprüfung, ...
# Wissenschaftlicher Mitarbeiter            [Wissenschaftlicher_Mitarbeiter_(Bundesdienst)...
# Wächter                                   [Wächter_(Begriffsklärung), United_States_Secr...
# Wärme-, Kälte- und Schallschutzisolierer  [Ausbildungsberuf, Berufsbildungsgesetz_(Deuts...
# Yogalehrer                                [Yoga, Indien, Ashram, Guru, Berufsbezeichnung...
# Zahlmeister                               [Militär, Offizier, Metapher, Journalist, Zeit...
# Zahnarzt                                  [Zahnmedizin, Deutsche_Demokratische_Republik,...
# Zahnmedizinischer Fachangestellter        [Zahnarzt, Ausbildung, Berufsschule, Sozialges...
# Zahnmedizinischer Fachassistent           [Zahnmedizinischer_Fachangestellter, Parodonti...
# Zahnmedizinischer Prophylaxeassistent     [Zahnmedizinischer_Fachangestellter, Arztpraxi...
# Zahnmedizinischer Verwaltungsassistent    [Aufstiegsfortbildung, Zahnmedizinischer_Facha...
# Zahntechniker                             [Handwerksordnung, Berufliche_Grundbildung, Za...
# Zauberer                                  [Die_Zauberin, Rune, persische_Magier, vates, ...
# Zerspanungsmechaniker                     [Zerspanen, Drehen_(Verfahren), Fräsen, Schlei...
# Zimmerer                                  [Zimmerer_(Begriffsklärung), Beruf, Holzbau, B...
# Zimmerpolier                                          [Polier, Holzbau, Handwerk, Zimmerer]
# Zinngießer                                [Simon_Marmion, Zinn, Zinnmarke, Zinnpest, Han...
# Zoologe                                   [Zoologie, Wissenschaft, Biologie, Tierarzt, F...
# Zootechniker                              [Frauenprießnitz, Deutsche_Demokratische_Repub...
# Zupfinstrumentenmacher                    [Gitarrenbau, Beruf, Zupfinstrument, Cister, B...
# Zuschneider                               [Schnittmuster, Schneider, Lehrling, Gesellenp...
# Zusteller                                 [Fachkraft, Briefzustellung, Deutsche_Post_AG,...
# Zweiradmechaniker                         [Zweiradmechatroniker, Beruf, Fahrrad, Motorra...
# Änderungsschneider                        [Schneider#Spezialschneider, Ausbildungsberuf,...
# Übersetzer                                [Sprachmittler, Dolmetscher, Text, Übersetzung...
#
#                                                                                        lead  \
# Abfallbeauftragter                        Ein Abfallbeauftragter oder Betriebsbeauftragt...
# Abt                                       Ein Abt (von spätlat. abbas, aus aram. abba „V...
# Account-Manager                           Der Account-Manager (AM, deutsch: Kundenbetreu...
# Altenpflegehelfer                         Altenpflegehilfe mit der Berufsbezeichnung Alt...
# Altenpfleger                              Altenpfleger und Altenpflegerinnen pflegen und...
# Amtsanwalt                                Ein Amtsanwalt ist in Deutschland ein Beamter ...
# Angestellter                              Ein Angestellter, auch Privatangestellter, ist...
# Animateur                                 Animateur (weibliche Form: Animateurin, von fr...
# Anlagenelektriker                         Anlagenelektriker war ein Lehrberuf in Österre...
# Anlagenmechaniker                         Der Anlagenmechaniker ist in Deutschland ein s...
# Anwendungsprogrammierer                   Anwendungsprogrammierer sind Programmierer, di...
# Anästhesietechnischer Assistent           Die Berufsgruppe Anästhesietechnische(r) Assis...
# Apothekenfacharbeiter                     Ein Apothekenfacharbeiter war ein Beruf in der...
# Apotheker                                 Apotheker sind Fachkräfte für Arzneimittel. Si...
# Apothekerassistent                        Ein Apothekerassistent, umgangssprachlich auch...
# Apothekerin                               Apothekerin bezeichnet\neine weibliche Person,...
# Arbeitserzieher                           Arbeitserzieher planen und gestalten arbeitser...
# Arbeitsvermittler                         Die Tätigkeit eines Arbeitsvermittlers ist auf...
# Architekt                                 Der Architekt (griech. ἀρχιτέκτων architékton,...
# Archivar                                  Der Archivar übernimmt, bewertet, erschließt u...
# Arrangeur                                 Ein musikalischer Arrangeur ist der Einrichter...
# Artist (Darsteller)                       Ein Artist (von mittellateinisch artista u. fr...
# Arzt                                      Ein Arzt beschäftigt sich mit der Vorbeugung (...
# Asphaltbauer                              Asphaltbauer (auch Asphaltierer oder veraltet ...
# Assistenzarzt
# Astronom                                  Ein Astronom (griechisch ἄστρον ástron ‚Stern‘...
# Astrophysiker                             Astrophysiker sind Forscher, die sich mit der ...
# Au-pair                                   Au-pair [oˈpɛʀ] (Kurzform für „Au-pair-Junge“ ...
# Audiodesign                               Audiodesign nennt sich die Gestaltung von Tona...
# Aufbereitungsmechaniker                   Der Aufbereitungsmechaniker beschäftigt sich m...
# ...                                                                                     ...
# Wildhüter                                 Wildhüter ist eine von mehreren Berufsbezeichn...
# Winzer                                     Winzer ist der mit dem Weinbau verbundene Beruf.
# Wirtschaftsassistent                      Staatlich geprüfter Wirtschaftsassistent ist e...
# Wirtschaftsfachwirt                       Geprüfter Wirtschaftsfachwirt ist ein öffentli...
# Wirtschaftsjurist                         Wirtschaftsjurist ist die Bezeichnung eines Ho...
# Wirtschaftsprüfer                         Wirtschaftsprüfer (häufig abgekürzt WP) ist ei...
# Wissenschaftlicher Mitarbeiter            Als wissenschaftliche Mitarbeiter werden Anges...
# Wächter                                   Wächter (mittelhochdeutsch: wahtäre, althochde...
# Wärme-, Kälte- und Schallschutzisolierer  Der Wärme-, Kälte- und Schallschutzisolierer i...
# Yogalehrer                                Ein Yogalehrer unterrichtet Yoga. Der Unterric...
# Zahlmeister                               Unter Zahlmeister versteht man allgemein eine ...
# Zahnarzt                                  Zahnarzt ist die Berufsbezeichnung für einen A...
# Zahnmedizinischer Fachangestellter        Ein Zahnmedizinischer Fachangestellter (ZFA) h...
# Zahnmedizinischer Fachassistent           Der Zahnmedizinische Fachassistent (ZMF) ist d...
# Zahnmedizinischer Prophylaxeassistent     Der zahnmedizinische Prophylaxeassistent (ZMP)...
# Zahnmedizinischer Verwaltungsassistent    Eine Zahnmedizinische Verwaltungsassistentin b...
# Zahntechniker                             Zahntechniker oder Zahnprothetiker ist in Deut...
# Zauberer                                  Als Zauberer oder Magier werden Menschen bezei...
# Zerspanungsmechaniker                     Zerspanungsmechaniker/-in bzw. Zerspanungstech...
# Zimmerer                                  Ein Zimmerer oder Zimmermann, weibliche Bezeic...
# Zimmerpolier                              Ein Zimmerpolier ist ein Polier für Zimmererar...
# Zinngießer                                Zinngießer ist eine Berufsbezeichnung und ein ...
# Zoologe                                   Ein Zoologe betreibt Zoologie als Wissenschaft...
# Zootechniker                              Zootechniker war ein landwirtschaftlicher Ausb...
# Zupfinstrumentenmacher                    Zupfinstrumentenmacher ist ein staatlich anerk...
# Zuschneider                               Zuschneider ist die Berufsbezeichnung für den ...
# Zusteller                                 Der Zusteller bezeichnet eine Fachkraft für di...
# Zweiradmechaniker                         Zweiradmechaniker (ab 1. November 2014 Zweirad...
# Änderungsschneider                        Der Änderungsschneider (ursprünglich Flickschn...
# Übersetzer                                Ein Übersetzer im engeren Sinne ist ein Sprach...
#
#                                                                                        text  \
# Abfallbeauftragter                        Ein Abfallbeauftragter oder Betriebsbeauftragt...
# Abt                                       Ein Abt (von spätlat. abbas, aus aram. abba „V...
# Account-Manager                           Der Account-Manager (AM, deutsch: Kundenbetreu...
# Altenpflegehelfer                         Altenpflegehilfe mit der Berufsbezeichnung Alt...
# Altenpfleger                              Altenpfleger und Altenpflegerinnen pflegen und...
# Amtsanwalt                                Ein Amtsanwalt ist in Deutschland ein Beamter ...
# Angestellter                              Ein Angestellter, auch Privatangestellter, ist...
# Animateur                                 Animateur (weibliche Form: Animateurin, von fr...
# Anlagenelektriker                         Anlagenelektriker war ein Lehrberuf in Österre...
# Anlagenmechaniker                         Der Anlagenmechaniker ist in Deutschland ein s...
# Anwendungsprogrammierer                   Anwendungsprogrammierer sind Programmierer, di...
# Anästhesietechnischer Assistent           Die Berufsgruppe Anästhesietechnische(r) Assis...
# Apothekenfacharbeiter                     Ein Apothekenfacharbeiter war ein Beruf in der...
# Apotheker                                 Apotheker sind Fachkräfte für Arzneimittel. Si...
# Apothekerassistent                        Ein Apothekerassistent, umgangssprachlich auch...
# Apothekerin                               Apothekerin bezeichnet\neine weibliche Person,...
# Arbeitserzieher                           Arbeitserzieher planen und gestalten arbeitser...
# Arbeitsvermittler                         Die Tätigkeit eines Arbeitsvermittlers ist auf...
# Architekt                                 Der Architekt (griech. ἀρχιτέκτων architékton,...
# Archivar                                  Der Archivar übernimmt, bewertet, erschließt u...
# Arrangeur                                 Ein musikalischer Arrangeur ist der Einrichter...
# Artist (Darsteller)                       Ein Artist (von mittellateinisch artista u. fr...
# Arzt                                      Ein Arzt beschäftigt sich mit der Vorbeugung (...
# Asphaltbauer                              Asphaltbauer (auch Asphaltierer oder veraltet ...
# Assistenzarzt                             \n== Deutschland ==\nEin Assistenzarzt ist ein...
# Astronom                                  Ein Astronom (griechisch ἄστρον ástron ‚Stern‘...
# Astrophysiker                             Astrophysiker sind Forscher, die sich mit der ...
# Au-pair                                   Au-pair [oˈpɛʀ] (Kurzform für „Au-pair-Junge“ ...
# Audiodesign                               Audiodesign nennt sich die Gestaltung von Tona...
# Aufbereitungsmechaniker                   Der Aufbereitungsmechaniker beschäftigt sich m...
# ...                                                                                     ...
# Wildhüter                                 Wildhüter ist eine von mehreren Berufsbezeichn...
# Winzer                                    Winzer ist der mit dem Weinbau verbundene Beru...
# Wirtschaftsassistent                      Staatlich geprüfter Wirtschaftsassistent ist e...
# Wirtschaftsfachwirt                       Geprüfter Wirtschaftsfachwirt ist ein öffentli...
# Wirtschaftsjurist                         Wirtschaftsjurist ist die Bezeichnung eines Ho...
# Wirtschaftsprüfer                         Wirtschaftsprüfer (häufig abgekürzt WP) ist ei...
# Wissenschaftlicher Mitarbeiter            Als wissenschaftliche Mitarbeiter werden Anges...
# Wächter                                   Wächter (mittelhochdeutsch: wahtäre, althochde...
# Wärme-, Kälte- und Schallschutzisolierer  Der Wärme-, Kälte- und Schallschutzisolierer i...
# Yogalehrer                                Ein Yogalehrer unterrichtet Yoga. Der Unterric...
# Zahlmeister                               Unter Zahlmeister versteht man allgemein eine ...
# Zahnarzt                                  Zahnarzt ist die Berufsbezeichnung für einen A...
# Zahnmedizinischer Fachangestellter        Ein Zahnmedizinischer Fachangestellter (ZFA) h...
# Zahnmedizinischer Fachassistent           Der Zahnmedizinische Fachassistent (ZMF) ist d...
# Zahnmedizinischer Prophylaxeassistent     Der zahnmedizinische Prophylaxeassistent (ZMP)...
# Zahnmedizinischer Verwaltungsassistent    Eine Zahnmedizinische Verwaltungsassistentin b...
# Zahntechniker                             Zahntechniker oder Zahnprothetiker ist in Deut...
# Zauberer                                  Als Zauberer oder Magier werden Menschen bezei...
# Zerspanungsmechaniker                     Zerspanungsmechaniker/-in bzw. Zerspanungstech...
# Zimmerer                                  Ein Zimmerer oder Zimmermann, weibliche Bezeic...
# Zimmerpolier                              Ein Zimmerpolier ist ein Polier für Zimmererar...
# Zinngießer                                Zinngießer ist eine Berufsbezeichnung und ein ...
# Zoologe                                   Ein Zoologe betreibt Zoologie als Wissenschaft...
# Zootechniker                              Zootechniker war ein landwirtschaftlicher Ausb...
# Zupfinstrumentenmacher                    Zupfinstrumentenmacher ist ein staatlich anerk...
# Zuschneider                               Zuschneider ist die Berufsbezeichnung für den ...
# Zusteller                                 Der Zusteller bezeichnet eine Fachkraft für di...
# Zweiradmechaniker                         Zweiradmechaniker (ab 1. November 2014 Zweirad...
# Änderungsschneider                        Der Änderungsschneider (ursprünglich Flickschn...
# Übersetzer                                Ein Übersetzer im engeren Sinne ist ein Sprach...
#
#                                                                                 male_person  \
# Abfallbeauftragter                                                                       []
# Abt                                       [Karl_Martell, Leo_X., Franz_I._(Frankreich), ...
# Account-Manager                                                                          []
# Altenpflegehelfer                                                                        []
# Altenpfleger                                                                             []
# Amtsanwalt                                                                               []
# Angestellter                              [Fritz_Croner, Michel_Crozier, Arnd_Zschiesche...
# Animateur                                                                                []
# Anlagenelektriker                                                                        []
# Anlagenmechaniker                                                                        []
# Anwendungsprogrammierer                                                                  []
# Anästhesietechnischer Assistent                                                          []
# Apothekenfacharbeiter                                                                    []
# Apotheker                                 [Léo_Apotheker, Friedrich_II._(HRR), Friedrich...
# Apothekerassistent                                                                       []
# Apothekerin                                                                              []
# Arbeitserzieher                                                                          []
# Arbeitsvermittler                                                                        []
# Architekt                                                   [Eugène_Viollet-le-Duc, Vitruv]
# Archivar                                                             [Michael_Diefenbacher]
# Arrangeur                                 [Leonard_Bernstein, Irwin_Kostal, George_Gersh...
# Artist (Darsteller)                                        [Enrico_Rastelli, Omar_Kingsley]
# Arzt                                      [Elmar_Brähler, Otto_F._Kernberg, Pantaleon_(H...
# Asphaltbauer                                                                             []
# Assistenzarzt                                                                            []
# Astronom                                     [Jan_Vermeer, Galileo_Galilei, Wilhelm_Olbers]
# Astrophysiker                                                                            []
# Au-pair                                                                                  []
# Audiodesign                                                                              []
# Aufbereitungsmechaniker                                                                  []
# ...                                                                                     ...
# Wildhüter                                                                                []
# Winzer                                    [Jost_Amman, Cyriacus_(Heiliger), Urban_von_La...
# Wirtschaftsassistent                                                                     []
# Wirtschaftsfachwirt                                                                      []
# Wirtschaftsjurist                                                                        []
# Wirtschaftsprüfer                                                      [Reinhard_Goerdeler]
# Wissenschaftlicher Mitarbeiter                                                           []
# Wächter                                                                                  []
# Wärme-, Kälte- und Schallschutzisolierer                                                 []
# Yogalehrer                                                                               []
# Zahlmeister                                                                              []
# Zahnarzt                                  [Pierre_Fauchard, Edward_H._Angle, Sanford_Chr...
# Zahnmedizinischer Fachangestellter                                                       []
# Zahnmedizinischer Fachassistent                                                          []
# Zahnmedizinischer Prophylaxeassistent                                                    []
# Zahnmedizinischer Verwaltungsassistent                                                   []
# Zahntechniker                                                                            []
# Zauberer                                  [Imhotep, Simon_Magus, Simon_Petrus, Albertus_...
# Zerspanungsmechaniker                                                                    []
# Zimmerer                                  [John_Everett_Millais, Josef_von_Nazaret, Joha...
# Zimmerpolier                                                                             []
# Zinngießer                                [Simon_Marmion, Friedrich_Herlin, Franz_Maria_...
# Zoologe                                   [Georg_Birukow, Alfred_Brehm, Ambroise_Marie_F...
# Zootechniker                                                             [Arnd_Bauerkämper]
# Zupfinstrumentenmacher                    [Glenn_Branca, Yuri_Landman, Harry_Partch, Han...
# Zuschneider                                                                              []
# Zusteller                                 [Franz_Schubert, Franz_Schubert#Lieder, Carl_Z...
# Zweiradmechaniker                                                                        []
# Änderungsschneider                                                                       []
# Übersetzer                                                               [Maurice_Blanchot]
#
#                                                                               female_person  \
# Abfallbeauftragter                                                                       []
# Abt                                                                                      []
# Account-Manager                                                                          []
# Altenpflegehelfer                                                                        []
# Altenpfleger                                                                             []
# Amtsanwalt                                                                               []
# Angestellter                                                                 [Irmgard_Keun]
# Animateur                                                                                []
# Anlagenelektriker                                                                        []
# Anlagenmechaniker                                                                        []
# Anwendungsprogrammierer                                                                  []
# Anästhesietechnischer Assistent                                                          []
# Apothekenfacharbeiter                                                                    []
# Apotheker                                                                  [Magdalena_Meub]
# Apothekerassistent                                                                       []
# Apothekerin                                                                              []
# Arbeitserzieher                                                                          []
# Arbeitsvermittler                                    [Henriette_Heber, Christine_Rädlinger]
# Architekt                                                                                []
# Archivar                                                           [Gertrude_Cepl-Kaufmann]
# Arrangeur                                 [Carla_Bley, Melba_Liston, Maria_Schneider_(Ko...
# Artist (Darsteller)                       [Lily_Braun, Caroline_Loyo, Therese_Renz, Jenn...
# Arzt                                                                                     []
# Asphaltbauer                                                                             []
# Assistenzarzt                                                                            []
# Astronom                                                                                 []
# Astrophysiker                                                                            []
# Au-pair                                                                                  []
# Audiodesign                                                                              []
# Aufbereitungsmechaniker                                                                  []
# ...                                                                                     ...
# Wildhüter                                                                                []
# Winzer                                                                                   []
# Wirtschaftsassistent                                                                     []
# Wirtschaftsfachwirt                                                                      []
# Wirtschaftsjurist                                                                        []
# Wirtschaftsprüfer                                                                        []
# Wissenschaftlicher Mitarbeiter                                                           []
# Wächter                                                                                  []
# Wärme-, Kälte- und Schallschutzisolierer                                                 []
# Yogalehrer                                                                               []
# Zahlmeister                                                                              []
# Zahnarzt                                    [Apollonia_von_Alexandria, Maria_Schug-Kösters]
# Zahnmedizinischer Fachangestellter                                                       []
# Zahnmedizinischer Fachassistent                                                          []
# Zahnmedizinischer Prophylaxeassistent                                                    []
# Zahnmedizinischer Verwaltungsassistent                                                   []
# Zahntechniker                                                                            []
# Zauberer                                  [Mina_Crandon, Tonke_Dragt, Susanna_Clarke, El...
# Zerspanungsmechaniker                                                                    []
# Zimmerer                                                                                 []
# Zimmerpolier                                                                             []
# Zinngießer                                                       [Katharina_II._(Russland)]
# Zoologe                                   [Amalie_Dietrich, Dian_Fossey, Jane_Goodall, B...
# Zootechniker                                                                             []
# Zupfinstrumentenmacher                                                                   []
# Zuschneider                                                                              []
# Zusteller                                                                                []
# Zweiradmechaniker                                                                        []
# Änderungsschneider                                                                       []
# Übersetzer                                                                               []
#
#                                           female_person_amount     Bias  \
# Abfallbeauftragter                                           0     male
# Abt                                                          0     male
# Account-Manager                                              0     male
# Altenpflegehelfer                                            0     male
# Altenpfleger                                                 0     male
# Amtsanwalt                                                   0     male
# Angestellter                                                 1     male
# Animateur                                                    0     male
# Anlagenelektriker                                            0     male
# Anlagenmechaniker                                            0     male
# Anwendungsprogrammierer                                      0     male
# Anästhesietechnischer Assistent                              0     male
# Apothekenfacharbeiter                                        0     male
# Apotheker                                                    1  neutral
# Apothekerassistent                                           0     male
# Apothekerin                                                  0  neutral
# Arbeitserzieher                                              0     male
# Arbeitsvermittler                                            2     male
# Architekt                                                    0     male
# Archivar                                                     1     male
# Arrangeur                                                    4     male
# Artist (Darsteller)                                          7     male
# Arzt                                                         0     male
# Asphaltbauer                                                 0     male
# Assistenzarzt                                                0     male
# Astronom                                                     0     male
# Astrophysiker                                                0     male
# Au-pair                                                      0  neutral
# Audiodesign                                                  0  neutral
# Aufbereitungsmechaniker                                      0     male
# ...                                                        ...      ...
# Wildhüter                                                    0     male
# Winzer                                                       0     male
# Wirtschaftsassistent                                         0     male
# Wirtschaftsfachwirt                                          0     male
# Wirtschaftsjurist                                            0     male
# Wirtschaftsprüfer                                            0     male
# Wissenschaftlicher Mitarbeiter                               0     male
# Wächter                                                      0     male
# Wärme-, Kälte- und Schallschutzisolierer                     0     male
# Yogalehrer                                                   0     male
# Zahlmeister                                                  0     male
# Zahnarzt                                                     2     male
# Zahnmedizinischer Fachangestellter                           0     male
# Zahnmedizinischer Fachassistent                              0     male
# Zahnmedizinischer Prophylaxeassistent                        0     male
# Zahnmedizinischer Verwaltungsassistent                       0     male
# Zahntechniker                                                0     male
# Zauberer                                                     4     male
# Zerspanungsmechaniker                                        0     male
# Zimmerer                                                     0     male
# Zimmerpolier                                                 0     male
# Zinngießer                                                   1     male
# Zoologe                                                      4     male
# Zootechniker                                                 0     male
# Zupfinstrumentenmacher                                       0     male
# Zuschneider                                                  0     male
# Zusteller                                                    0     male
# Zweiradmechaniker                                            0     male
# Änderungsschneider                                           0     male
# Übersetzer                                                   0     male
#
#                                          prof_gender labor_market_domin  \
# Abfallbeauftragter                              male               male
# Abt                                             male             female
# Account-Manager                                 male               male
# Altenpflegehelfer                               male             female
# Altenpfleger                                    male             female
# Amtsanwalt                                      male             female
# Angestellter                                    male               None
# Animateur                                       male             female
# Anlagenelektriker                               male               male
# Anlagenmechaniker                               male               male
# Anwendungsprogrammierer                         male               male
# Anästhesietechnischer Assistent                 male             female
# Apothekenfacharbeiter                           male             female
# Apotheker                                       male             female
# Apothekerassistent                              male             female
# Apothekerin                                   female             female
# Arbeitserzieher                                 male             female
# Arbeitsvermittler                               male             female
# Architekt                                       male               male
# Archivar                                        male             female
# Arrangeur                                       male               male
# Artist (Darsteller)                             male               male
# Arzt                                            male             female
# Asphaltbauer                                    male               male
# Assistenzarzt                                   male             female
# Astronom                                        male               male
# Astrophysiker                                   male               male
# Au-pair                                      neutral             female
# Audiodesign                                  neutral               male
# Aufbereitungsmechaniker                         male               male
# ...                                              ...                ...
# Wildhüter                                       male               male
# Winzer                                          male               male
# Wirtschaftsassistent                            male             female
# Wirtschaftsfachwirt                             male             female
# Wirtschaftsjurist                               male             female
# Wirtschaftsprüfer                               male               male
# Wissenschaftlicher Mitarbeiter                  male               male
# Wächter                                         male               male
# Wärme-, Kälte- und Schallschutzisolierer        male               male
# Yogalehrer                                      male             female
# Zahlmeister                                     male               male
# Zahnarzt                                        male             female
# Zahnmedizinischer Fachangestellter              male             female
# Zahnmedizinischer Fachassistent                 male             female
# Zahnmedizinischer Prophylaxeassistent           male             female
# Zahnmedizinischer Verwaltungsassistent          male             female
# Zahntechniker                                   male             female
# Zauberer                                        male               male
# Zerspanungsmechaniker                           male               male
# Zimmerer                                        male               male
# Zimmerpolier                                    male               male
# Zinngießer                                      male               male
# Zoologe                                         male               male
# Zootechniker                                    male               male
# Zupfinstrumentenmacher                          male               male
# Zuschneider                                     male             female
# Zusteller                                       male               male
# Zweiradmechaniker                               male               male
# Änderungsschneider                              male             female
# Übersetzer                                      male             female
#
#                                                                         profession
# Abfallbeauftragter                                              Abfallbeauftragter
# Abt                                                                            Abt
# Account-Manager                                                    Account-Manager
# Altenpflegehelfer                                                Altenpflegehelfer
# Altenpfleger                                                          Altenpfleger
# Amtsanwalt                                                              Amtsanwalt
# Angestellter                                                          Angestellter
# Animateur                                                                Animateur
# Anlagenelektriker                                                Anlagenelektriker
# Anlagenmechaniker                                                Anlagenmechaniker
# Anwendungsprogrammierer                                    Anwendungsprogrammierer
# Anästhesietechnischer Assistent                    Anästhesietechnischer Assistent
# Apothekenfacharbeiter                                        Apothekenfacharbeiter
# Apotheker                                                                Apotheker
# Apothekerassistent                                              Apothekerassistent
# Apothekerin                                                            Apothekerin
# Arbeitserzieher                                                    Arbeitserzieher
# Arbeitsvermittler                                                Arbeitsvermittler
# Architekt                                                                Architekt
# Archivar                                                                  Archivar
# Arrangeur                                                                Arrangeur
# Artist (Darsteller)                                            Artist (Darsteller)
# Arzt                                                                          Arzt
# Asphaltbauer                                                          Asphaltbauer
# Assistenzarzt                                                        Assistenzarzt
# Astronom                                                                  Astronom
# Astrophysiker                                                        Astrophysiker
# Au-pair                                                                    Au-pair
# Audiodesign                                                            Audiodesign
# Aufbereitungsmechaniker                                    Aufbereitungsmechaniker
# ...                                                                            ...
# Wildhüter                                                                Wildhüter
# Winzer                                                                      Winzer
# Wirtschaftsassistent                                          Wirtschaftsassistent
# Wirtschaftsfachwirt                                            Wirtschaftsfachwirt
# Wirtschaftsjurist                                                Wirtschaftsjurist
# Wirtschaftsprüfer                                                Wirtschaftsprüfer
# Wissenschaftlicher Mitarbeiter                      Wissenschaftlicher Mitarbeiter
# Wächter                                                                    Wächter
# Wärme-, Kälte- und Schallschutzisolierer  Wärme-, Kälte- und Schallschutzisolierer
# Yogalehrer                                                              Yogalehrer
# Zahlmeister                                                            Zahlmeister
# Zahnarzt                                                                  Zahnarzt
# Zahnmedizinischer Fachangestellter              Zahnmedizinischer Fachangestellter
# Zahnmedizinischer Fachassistent                    Zahnmedizinischer Fachassistent
# Zahnmedizinischer Prophylaxeassistent        Zahnmedizinischer Prophylaxeassistent
# Zahnmedizinischer Verwaltungsassistent      Zahnmedizinischer Verwaltungsassistent
# Zahntechniker                                                        Zahntechniker
# Zauberer                                                                  Zauberer
# Zerspanungsmechaniker                                        Zerspanungsmechaniker
# Zimmerer                                                                  Zimmerer
# Zimmerpolier                                                          Zimmerpolier
# Zinngießer                                                              Zinngießer
# Zoologe                                                                    Zoologe
# Zootechniker                                                          Zootechniker
# Zupfinstrumentenmacher                                      Zupfinstrumentenmacher
# Zuschneider                                                            Zuschneider
# Zusteller                                                                Zusteller
# Zweiradmechaniker                                                Zweiradmechaniker
# Änderungsschneider                                              Änderungsschneider
# Übersetzer                                                              Übersetzer
#
# [885 rows x 11 columns]

# %%
print "No labour market data for these professions (they are too general):"
about_pages[about_pages.labor_market_domin.isnull()]
# Out:
# No labour market data for these professions (they are too general):
#                       male_person_amount  \
# Angestellter                           7
# Facharbeiter                           0
# Fachkaufmann                           0
# Fachkraft                              0
# Fachleiter                             0
# Fachpraktiker                          0
# Helfer                                 6
# Kaufmann                               0
# Meister                                0
# Produktionshelfer                      0
# Sachverständiger                       2
# Techniker                              0
# Trainer                                1
# Verfahrensmechaniker                   0
#
#                                                                all_link  \
# Angestellter          [Arbeitnehmer, Arbeiter, Arbeitsrecht, Sozialr...
# Facharbeiter          [Fachkraft, Ausbildung, Berufsausbildungsverhä...
# Fachkaufmann          [Aufstiegsfortbildung, Industrie-_und_Handelsk...
# Fachkraft             [Eisenbahnbau, Sicherung_von_Zugfahrten, Beruf...
# Fachleiter            [Lehrer, Schule, Studienseminar, Fachkonferenz...
# Fachpraktiker         [Auszubildende, Berufsausbildung, Behinderung_...
# Helfer                [Hilfe, Technisches_Hilfswerk, Helfer_vor_Ort,...
# Kaufmann              [Kaufmann_(Begriffsklärung), Kaufmann_(Familie...
# Meister               [Meister_(Begriffsklärung), Latein, Magister, ...
# Produktionshelfer     [Hilfsarbeiter, Arbeiter, Arbeitnehmerüberlass...
# Sachverständiger      [Fachkompetenz, Experte, Rechtsfrage-Sachfrage...
# Techniker             [Technik, Berufsbezeichnung, Aufstiegsweiterbi...
# Trainer               [Trainer_(Begriffsklärung), Sport, Mannschafts...
# Verfahrensmechaniker  [Autoklav#Dampfhärtung, Kalksandstein, Metalli...
#
#                                                                    lead  \
# Angestellter          Ein Angestellter, auch Privatangestellter, ist...
# Facharbeiter          Facharbeiter ist eine qualifizierte Fachkraft ...
# Fachkaufmann          Der Fachkaufmann ist eine betriebswirtschaftli...
# Fachkraft             Eine Fachkraft ist allgemein eine Person, die ...
# Fachleiter            Fachleiter bilden angehende Lehrer im Rahmen d...
# Fachpraktiker         Fachpraktiker bzw. Werker werden in Deutschlan...
# Helfer                Helfer steht für:\neine Person, die in irgende...
# Kaufmann              Ein Kaufmann ist eine Person, die erwerbsmäßig...
# Meister               Meister (v. lat.: „Magister“ für „Lehrer“, eng...
# Produktionshelfer     Ein Produktionshelfer ist ein Hilfsarbeiter im...
# Sachverständiger      Ein Sachverständiger ist eine natürliche Perso...
# Techniker             Als Techniker werden häufig Berufsgruppen oder...
# Trainer               Trainer (englisch to train ‚ausbilden; dressie...
# Verfahrensmechaniker  Verfahrensmechaniker sind überwiegend in der m...
#
#                                                                    text  \
# Angestellter          Ein Angestellter, auch Privatangestellter, ist...
# Facharbeiter          Facharbeiter ist eine qualifizierte Fachkraft ...
# Fachkaufmann          Der Fachkaufmann ist eine betriebswirtschaftli...
# Fachkraft             Eine Fachkraft ist allgemein eine Person, die ...
# Fachleiter            Fachleiter bilden angehende Lehrer im Rahmen d...
# Fachpraktiker         Fachpraktiker bzw. Werker werden in Deutschlan...
# Helfer                Helfer steht für:\neine Person, die in irgende...
# Kaufmann              Ein Kaufmann ist eine Person, die erwerbsmäßig...
# Meister               Meister (v. lat.: „Magister“ für „Lehrer“, eng...
# Produktionshelfer     Ein Produktionshelfer ist ein Hilfsarbeiter im...
# Sachverständiger      Ein Sachverständiger ist eine natürliche Perso...
# Techniker             Als Techniker werden häufig Berufsgruppen oder...
# Trainer               Trainer (englisch to train ‚ausbilden; dressie...
# Verfahrensmechaniker  Verfahrensmechaniker sind überwiegend in der m...
#
#                                                             male_person  \
# Angestellter          [Fritz_Croner, Michel_Crozier, Arnd_Zschiesche...
# Facharbeiter                                                         []
# Fachkaufmann                                                         []
# Fachkraft                                                            []
# Fachleiter                                                           []
# Fachpraktiker                                                        []
# Helfer                [Armin_Helfer, Christian_Helfer, Erwin_Helfer,...
# Kaufmann                                                             []
# Meister                                                              []
# Produktionshelfer                                                    []
# Sachverständiger             [Anton_Schäfer_(Rechtsanwalt), Dirk_Olzen]
# Techniker                                                            []
# Trainer                                                   [Arnd_Krüger]
# Verfahrensmechaniker                                                 []
#
#                                        female_person  female_person_amount  \
# Angestellter                          [Irmgard_Keun]                     1
# Facharbeiter                                      []                     0
# Fachkaufmann                                      []                     0
# Fachkraft                                         []                     0
# Fachleiter                                        []                     0
# Fachpraktiker                                     []                     0
# Helfer                [Monika_Helfer, Tricia_Helfer]                     2
# Kaufmann                                          []                     0
# Meister                                           []                     0
# Produktionshelfer                                 []                     0
# Sachverständiger                                  []                     0
# Techniker                                         []                     0
# Trainer                                           []                     0
# Verfahrensmechaniker                              []                     0
#
#                          Bias prof_gender labor_market_domin  \
# Angestellter             male        male               None
# Facharbeiter             male        male               None
# Fachkaufmann             male        male               None
# Fachkraft             neutral     neutral               None
# Fachleiter               male        male               None
# Fachpraktiker            male        male               None
# Helfer                   male        male               None
# Kaufmann                 male        male               None
# Meister                  male        male               None
# Produktionshelfer        male        male               None
# Sachverständiger         male        male               None
# Techniker                male        male               None
# Trainer                  male        male               None
# Verfahrensmechaniker     male        male               None
#
#                                 profession
# Angestellter                  Angestellter
# Facharbeiter                  Facharbeiter
# Fachkaufmann                  Fachkaufmann
# Fachkraft                        Fachkraft
# Fachleiter                      Fachleiter
# Fachpraktiker                Fachpraktiker
# Helfer                              Helfer
# Kaufmann                          Kaufmann
# Meister                            Meister
# Produktionshelfer        Produktionshelfer
# Sachverständiger          Sachverständiger
# Techniker                        Techniker
# Trainer                            Trainer
# Verfahrensmechaniker  Verfahrensmechaniker
